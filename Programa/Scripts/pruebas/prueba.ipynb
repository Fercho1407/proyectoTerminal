# %%
import pandas as pd

# %%
df = pd.read_csv("../../Datos/datasets_procesados/ventas_normalizado.csv")

# %%
nulos_por_columna = df.isnull().sum()
print("nulos por columna: ", nulos_por_columna)
# Out:
# nulos por columna:  Unnamed: 0         0
# fecha              0
# product_name       0
# category_off       0
# ventas             0
# precio             0
# perecedero         0
# en_temporada       0
# temp_inicio_mes    0
# temp_fin_mes       0
# dtype: int64

# %%
filas_con_nulos = df[df.isnull().any(axis=1)]

# Muestra el resultado (en Jupyter usar 'display' se ve más bonito que 'print')
display(filas_con_nulos)

filas_con_nulos['product_name'].unique()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, fecha, product_name, category_off, ventas, precio, perecedero, en_temporada, temp_inicio_mes, temp_fin_mes]
# Index: []
# <StringArray>
# []
# Length: 0, dtype: str
